# %%
#Today Tasks:
1. #From Given Numbers a,b,c 
            # print a+b+c if a,b,c are not euqal
            # print value of c if a = b but a !=c
            # print value of b if a = c but a!=b
            # print value of a if b = c  but b!=a
            # print "Zero" if a =b =c
            
2. define a function which guess a number generated by random module

3. Print number of Even and Odd nums in given range and also print their difference also.

4. Delevlop a logic user name and password validation of user login 
   and display the welcome to valid users.
    
5. Using if conditions print the biggest of 3 numbers.

6. Python Program to print all numbers in a range divisible by a given number.

7. Python Program to Reverse a Given Number
8. Python Program to Find the Sum of Digits in a Number

9. Python Program to Count the Number of Digits in a Number

10. Python Program to check if a number is a Perfect number.
